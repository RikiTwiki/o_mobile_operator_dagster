# %%
hourly_stats = [
    {"date": "00:00:00", "total_handled_chats": 265, "total_by_operator": 33, "bot_handled_chats": 232,
     "average_reaction_time": 8.546979865771812, "average_speed_to_answer": 10.875757575757576,
     "user_total_reaction_time": 14356, "user_count_replies": 1320, "total_chats": 106},
    {"date": "01:00:00", "total_handled_chats": 259, "total_by_operator": 45, "bot_handled_chats": 214,
     "average_reaction_time": 9.326860841423947, "average_speed_to_answer": 14.030322173089071,
     "user_total_reaction_time": 22210, "user_count_replies": 1583, "total_chats": 50},
    {"date": "02:00:00", "total_handled_chats": 210, "total_by_operator": 11, "bot_handled_chats": 199,
     "average_reaction_time": 5.711711711711712, "average_speed_to_answer": 8.57917760279965,
     "user_total_reaction_time": 9806, "user_count_replies": 1143, "total_chats": 45},
    {"date": "03:00:00", "total_handled_chats": 180, "total_by_operator": 9, "bot_handled_chats": 171,
     "average_reaction_time": 5.926315789473684, "average_speed_to_answer": 8.620650953984287,
     "user_total_reaction_time": 7681, "user_count_replies": 891, "total_chats": 26},
    {"date": "04:00:00", "total_handled_chats": 187, "total_by_operator": 4, "bot_handled_chats": 183,
     "average_reaction_time": 4.9375, "average_speed_to_answer": 7.579691516709512,
     "user_total_reaction_time": 5897, "user_count_replies": 778, "total_chats": 13},
    {"date": "05:00:00", "total_handled_chats": 166, "total_by_operator": 2, "bot_handled_chats": 164,
     "average_reaction_time": 5.154761904761905, "average_speed_to_answer": 7.172699069286453,
     "user_total_reaction_time": 6936, "user_count_replies": 967, "total_chats": 23},
    {"date": "06:00:00", "total_handled_chats": 156, "total_by_operator": 13, "bot_handled_chats": 143,
     "average_reaction_time": 16.63005780346821, "average_speed_to_answer": 13.714285714285714,
     "user_total_reaction_time": 10176, "user_count_replies": 742, "total_chats": 38},
    {"date": "07:00:00", "total_handled_chats": 153, "total_by_operator": 7, "bot_handled_chats": 146,
     "average_reaction_time": 6.453416149068323, "average_speed_to_answer": 8.28918918918919,
     "user_total_reaction_time": 6134, "user_count_replies": 740, "total_chats": 40},
    {"date": "08:00:00", "total_handled_chats": 189, "total_by_operator": 24, "bot_handled_chats": 165,
     "average_reaction_time": 9.721461187214611, "average_speed_to_answer": 11.936299292214358,
     "user_total_reaction_time": 11805, "user_count_replies": 989, "total_chats": 83},
    {"date": "09:00:00", "total_handled_chats": 162, "total_by_operator": 33, "bot_handled_chats": 129,
     "average_reaction_time": 13.326633165829145, "average_speed_to_answer": 13.530506721820062,
     "user_total_reaction_time": 13084, "user_count_replies": 967, "total_chats": 142},
    {"date": "10:00:00", "total_handled_chats": 158, "total_by_operator": 38, "bot_handled_chats": 120,
     "average_reaction_time": 8.429292929292929, "average_speed_to_answer": 12.492972972972973,
     "user_total_reaction_time": 11556, "user_count_replies": 925, "total_chats": 184},
    {"date": "11:00:00", "total_handled_chats": 149, "total_by_operator": 45, "bot_handled_chats": 104,
     "average_reaction_time": 12.370192307692308, "average_speed_to_answer": 15.397626112759644,
     "user_total_reaction_time": 15567, "user_count_replies": 1011, "total_chats": 239},
    {"date": "12:00:00", "total_handled_chats": 142, "total_by_operator": 69, "bot_handled_chats": 73,
     "average_reaction_time": 20.65938864628821, "average_speed_to_answer": 22.061621621621622,
     "user_total_reaction_time": 20407, "user_count_replies": 925, "total_chats": 235},
    {"date": "13:00:00", "total_handled_chats": 100, "total_by_operator": 61, "bot_handled_chats": 39,
     "average_reaction_time": 27.15606936416185, "average_speed_to_answer": 26.888140161725067,
     "user_total_reaction_time": 19951, "user_count_replies": 742, "total_chats": 197},
    {"date": "14:00:00", "total_handled_chats": 83, "total_by_operator": 54, "bot_handled_chats": 29,
     "average_reaction_time": 57.56375838926174, "average_speed_to_answer": 32.69142857142857,
     "user_total_reaction_time": 22884, "user_count_replies": 700, "total_chats": 216},
    {"date": "15:00:00", "total_handled_chats": 78, "total_by_operator": 64, "bot_handled_chats": 14,
     "average_reaction_time": 28.21472392638037, "average_speed_to_answer": 23.9737876802097,
     "user_total_reaction_time": 18292, "user_count_replies": 763, "total_chats": 197},
    {"date": "16:00:00", "total_handled_chats": 45, "total_by_operator": 33, "bot_handled_chats": 12,
     "average_reaction_time": 18.36263736263736, "average_speed_to_answer": 20.397463002114165,
     "user_total_reaction_time": 9648, "user_count_replies": 473, "total_chats": 165},
    {"date": "17:00:00", "total_handled_chats": 67, "total_by_operator": 55, "bot_handled_chats": 12,
     "average_reaction_time": 24.735714285714284, "average_speed_to_answer": 20.669505962521295,
     "user_total_reaction_time": 12133, "user_count_replies": 587, "total_chats": 200},
    {"date": "18:00:00", "total_handled_chats": 89, "total_by_operator": 62, "bot_handled_chats": 27,
     "average_reaction_time": 24.858024691358025, "average_speed_to_answer": 20.127003699136868,
     "user_total_reaction_time": 16323, "user_count_replies": 811, "total_chats": 167},
    {"date": "19:00:00", "total_handled_chats": 90, "total_by_operator": 67, "bot_handled_chats": 23,
     "average_reaction_time": 23.903954802259886, "average_speed_to_answer": 22.54415274463007,
     "user_total_reaction_time": 18892, "user_count_replies": 838, "total_chats": 182},
    {"date": "20:00:00", "total_handled_chats": 118, "total_by_operator": 62, "bot_handled_chats": 56,
     "average_reaction_time": 17.237113402061855, "average_speed_to_answer": 16.20715036803365,
     "user_total_reaction_time": 15413, "user_count_replies": 951, "total_chats": 180},
    {"date": "21:00:00", "total_handled_chats": 154, "total_by_operator": 47, "bot_handled_chats": 107,
     "average_reaction_time": 11.270642201834862, "average_speed_to_answer": 11.670686456400742,
     "user_total_reaction_time": 12581, "user_count_replies": 1078, "total_chats": 226},
    {"date": "22:00:00", "total_handled_chats": 194, "total_by_operator": 59, "bot_handled_chats": 135,
     "average_reaction_time": 9.925650557620818, "average_speed_to_answer": 14.435321456235476,
     "user_total_reaction_time": 18636, "user_count_replies": 1291, "total_chats": 190},
    {"date": "23:00:00", "total_handled_chats": 247, "total_by_operator": 71, "bot_handled_chats": 176,
     "average_reaction_time": 12.460843373493976, "average_speed_to_answer": 15.195121951219512,
     "user_total_reaction_time": 24920, "user_count_replies": 1640, "total_chats": 156},
]

print(hourly_stats)
# Out:
# [{'date': '00:00:00', 'total_handled_chats': 265, 'total_by_operator': 33, 'bot_handled_chats': 232, 'average_reaction_time': 8.546979865771812, 'average_speed_to_answer': 10.875757575757577, 'user_total_reaction_time': 14356, 'user_count_replies': 1320, 'total_chats': 106}, {'date': '01:00:00', 'total_handled_chats': 259, 'total_by_operator': 45, 'bot_handled_chats': 214, 'average_reaction_time': 9.326860841423947, 'average_speed_to_answer': 14.03032217308907, 'user_total_reaction_time': 22210, 'user_count_replies': 1583, 'total_chats': 50}, {'date': '02:00:00', 'total_handled_chats': 210, 'total_by_operator': 11, 'bot_handled_chats': 199, 'average_reaction_time': 5.711711711711712, 'average_speed_to_answer': 8.57917760279965, 'user_total_reaction_time': 9806, 'user_count_replies': 1143, 'total_chats': 45}, {'date': '03:00:00', 'total_handled_chats': 180, 'total_by_operator': 9, 'bot_handled_chats': 171, 'average_reaction_time': 5.926315789473684, 'average_speed_to_answer': 8.620650
# ...

# %%
from basic_table import BasicTable

def render_hour_jivo_data_aggregated(items):
    """
    Аналог PHP-метода renderHourJivoDataAggregated, с настройкой полей и передачей items в BasicTable.
    Возвращает HTML строку таблицы.
    """
    table = BasicTable()
    table.Fields = [
        {"field": "date", "title": "Часы"},
        {"field": "total_chats", "title": "Поступило обращений", "summary": "sum"},
        {"field": "total_handled_chats", "title": "Обработано обращений", "summary": "sum"},
        {"field": "total_by_operator", "title": "Закрыто без задержки (операторами)", "summary": "sum"},
        {"field": "bot_handled_chats", "title": "Закрыто с задержкой 12 часов (чат-ботом)", "summary": "sum"},
        {"field": "average_reaction_time", "title": "Average Reaction Time", "paint": "asc", "round": 2},
        {"field": "average_speed_to_answer", "title": "Average Speed To Answer", "paint": "asc", "round": 2},
        {"field": "user_total_reaction_time", "title": "Chat Total Reaction Time", "paint": "asc", "round": 2},
        {"field": "user_count_replies", "title": "Chat Count Replies", "paint": "desc", "round": 2},
    ]
    table.Items = items
    return table.getTable()

# %%
from IPython.display import HTML, display

html = render_hour_jivo_data_aggregated(hourly_stats)  # items — список словарей с нужными полями

print(html)

display(HTML(html))
# Out:
# <table style='border: 1px solid  #32383e; border-collapse: collapse; font-size: 12;'><tr style='background-color: #f2f2f2;'><th style='color: #fff; border: 1px solid #32383e; text-align: center; padding-left: 3px; padding-right: 3px; background-color: #43484c; '>Часы</th><th style='color: #fff; border: 1px solid #32383e; text-align: center; padding-left: 3px; padding-right: 3px; background-color: #43484c; '>Поступило обращений</th><th style='color: #fff; border: 1px solid #32383e; text-align: center; padding-left: 3px; padding-right: 3px; background-color: #43484c; '>Обработано обращений</th><th style='color: #fff; border: 1px solid #32383e; text-align: center; padding-left: 3px; padding-right: 3px; background-color: #43484c; '>Закрыто без задержки (операторами)</th><th style='color: #fff; border: 1px solid #32383e; text-align: center; padding-left: 3px; padding-right: 3px; background-color: #43484c; '>Закрыто с задержкой 12 часов (чат-ботом)</th><th style='color: #fff; border: 1px s
# ...

# %%
# !pip install weasyprint PyPDF2
# Out:
# ...
#   Using cached pydyf-0.11.0-py3-none-any.whl.metadata (2.5 kB)
# ...
#   Using cached tinyhtml5-2.0.0-py3-none-any.whl.metadata (2.9 kB)
# ...
#   Using cached tinycss2-1.4.0-py3-none-any.whl.metadata (3.0 kB)
# ...
#   Using cached cssselect2-0.8.0-py3-none-any.whl.metadata (2.9 kB)
# ...
#   Using cached pyphen-0.17.2-py3-none-any.whl.metadata (3.2 kB)
# ...
#   Using cached pycparser-2.22-py3-none-any.whl.metadata (943 bytes)
# ...
#   Using cached webencodings-0.5.1-py2.py3-none-any.whl.metadata (2.1 kB)
# ...
# Using cached cssselect2-0.8.0-py3-none-any.whl (15 kB)
# ...
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.2 MB ? eta -:--:--
#    ------------- -------------------------- 0.8/2.2 MB 2.2 MB/s eta 0:00:01
#    ------------------ --------------------- 1.0/2.2 MB 1.8 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.3/2.2 MB 1.9 MB/s eta 0:00:01
#    -------------------------------- ------- 1.8/2.2 MB 1.8 MB/s eta 0:00:01
# ...

# %%
import os
os.environ["PATH"] = r"C:\msys64\mingw64\bin;" + os.environ["PATH"]

from weasyprint import HTML

print("WeasyPrint импортировался успешно")

from PyPDF2 import PdfReader, PdfWriter
from pathlib import Path

def html_to_pdf_file(html: str, out_path: str):
    HTML(string=html).write_pdf(out_path)

def html_to_pdf_bytes(html: str) -> bytes:
    return HTML(string=html).write_pdf()

def merge_pdfs(primary_pdf: str, append_pdf: str, output: str):
    writer = PdfWriter()
    for page in PdfReader(primary_pdf).pages:
        writer.add_page(page)
    for page in PdfReader(append_pdf).pages:
        writer.add_page(page)
    with open(output, "wb") as f:
        writer.write(f)
# Out:
# WeasyPrint импортировался успешно

# %%
html = render_hour_jivo_data_aggregated(hourly_stats)
HTML(string=html).write_pdf("jivo_table.pdf")

# %%
# !pip install tzdata
# Out:
# ...
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# ...

# %%
from datetime import datetime, timezone
import html

# попытка импортировать zoneinfo
try:
    from zoneinfo import ZoneInfo, ZoneInfoNotFoundError
except ImportError:  # старые версии или отсутствует
    ZoneInfo = None
    class ZoneInfoNotFoundError(Exception): pass

def resolve_tz(tz_name: str | None):
    if not tz_name:
        return timezone.utc
    if ZoneInfo:
        try:
            return ZoneInfo(tz_name)
        except ZoneInfoNotFoundError:
            pass
    # fallback: попробовать dateutil, если установлен
    try:
        from dateutil import tz as dateutil_tz
        du = dateutil_tz.gettz(tz_name)
        if du:
            return du
    except ImportError:
        pass
    # финальный fallback — UTC
    return timezone.utc

# %%
from datetime import timezone

from html_report_page import HtmlReportPage

tz = resolve_tz("Asia/Bishkek")

report = HtmlReportPage("Еженедельная аналитика", tz)
report.set_header("Технический отчёт по проекту", "nod")
report.add_block_header("Общая статистика")
report.add_module_header("Показатели по каналам")
report.add_text("Среднее время ответа выросло на 12%")
html = report.render()

print(html)
# Out:
# <!doctype html>
# <html lang="ru">
#   <head>
#     <meta charset="UTF-8" />
#     <meta name="viewport" content="width=device-width, initial-scale=1.0" />
#     <title>Технический отчёт по проекту</title>
#     <style>
#       body {
#         font-family: Calibri, Candara, Segoe, 'Segoe UI', Optima, Arial, sans-serif;
#         margin: 0;
#         padding: 16px;
#         background: #f9f9f9;
#         color: #1f1f1f;
#         line-height: 1.3;
#       }
#       a { color: inherit; }
#       .container { max-width: 1200px; margin: auto; background: #fff; padding: 16px; box-shadow: 0 4px 14px rgba(0,0,0,0.05); border-radius: 12px; }
#       .section { margin-bottom: 24px; }
#       .small { font-size: 12px; color: #555; }
#     </style>
#   </head>
#   <body>
#     <div class="container">
#
#             <table style="width:100%;border-collapse:collapse;margin-bottom:8px;">
#                 <tr>
# ...

# %%
display(HTML(html))
# Out:
# <!doctype html>
# <html lang="ru">
#   <head>
#     <meta charset="UTF-8" />
#     <meta name="viewport" content="width=device-width, initial-scale=1.0" />
#     <title>Технический отчёт по проекту</title>
#     <style>
#       body {
#         font-family: Calibri, Candara, Segoe, 'Segoe UI', Optima, Arial, sans-serif;
#         margin: 0;
#         padding: 16px;
#         background: #f9f9f9;
#         color: #1f1f1f;
#         line-height: 1.3;
#       }
#       a { color: inherit; }
#       .container { max-width: 1200px; margin: auto; background: #fff; padding: 16px; box-shadow: 0 4px 14px rgba(0,0,0,0.05); border-radius: 12px; }
#       .section { margin-bottom: 24px; }
#       .small { font-size: 12px; color: #555; }
#     </style>
#   </head>
#   <body>
#     <div class="container">
#
#             <table style="width:100%;border-collapse:collapse;margin-bottom:8px;">
#                 <tr>
# ...

# %%
HTML(string=html).write_pdf("jivo_table.pdf")

# %%
from html_to_pdf import HtmlToPdf

converter = HtmlToPdf(base_format="A4", width_scale=2.0)

pdf_path = converter.convert_to_file(html, "report_large_width.pdf")

print("Сохранено в", pdf_path)
# Out:
# Сохранено в report_large_width.pdf

# %%
# !pip install pyppeteer

# %%
import asyncio
from pyppeteer import launch
from pathlib import Path

async def html_to_single_page_pdf(html_path: str, output_pdf: str, scale: float = 1.0):
    html_path = Path(html_path).resolve()
    if not html_path.exists():
        raise FileNotFoundError(f"{html_path} не найден")

    browser = await launch()
    page = await browser.newPage()
    # Загружаем локальный файл. Надёжно через file:///
    await page.goto(f"file:///{html_path}", waitUntil="networkidle0")
    # Получаем полный размер контента
    width = await page.evaluate("() => document.documentElement.scrollWidth")
    height = await page.evaluate("() => document.documentElement.scrollHeight")

    await page.pdf(
        path=output_pdf,
        printBackground=True,
        width=f"{width * scale}px",
        height=f"{height * scale}px",
        margin={"top": 0, "bottom": 0, "left": 0, "right": 0},
    )
    await browser.close()
    print(f"Сохранено: {output_pdf}")

if __name__ == "__main__":
    import sys
    html_file = "report.html"
    out_pdf = "output.pdf"
    asyncio.run(html_to_single_page_pdf(html_file, out_pdf))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[14], line 32
#      30 html_file = "report.html"
#      31 out_pdf = "output.pdf"
# ---> 32 asyncio.run(html_to_single_page_pdf(html_file, out_pdf))
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\asyncio\runners.py:190, in run(main, debug, loop_factory)
#     161 """Execute the coroutine and return the result.
#     162
#     163 This function runs the passed coroutine, taking care of
#    (...)    186     asyncio.run(main())
#     187 """
#     188 if events._get_running_loop() is not None:
#     189     # fail fast with short traceback
# --> 190     raise RuntimeError(
#     191         "asyncio.run() cannot be called from a running event loop")
#     193 with Runner(debug=debug, loop_factory=loop_factory) as runner:
#     194     return runner.run(main)
#
# ...
